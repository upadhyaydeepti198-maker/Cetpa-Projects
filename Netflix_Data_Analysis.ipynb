# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv("Netflix Dataset.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
len(df.columns)
# Out:
# 11

# %%
print("Rows : ",df.shape[0])
print("Column : ",df.shape[1])
# Out:
# Rows :  7789
# Column :  11

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
df.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.sample(3)
# Out:
#      Show_Id Category                                        Title  \
# 4876   s4876  TV Show                              Planet Earth II
# 2829   s2830    Movie        Hotel Transylvania 3: Summer Vacation
# 4409   s4410    Movie  Naruto Shippuden: The Movie: The Lost Tower
#
#                 Director                                               Cast  \
# 4876                 NaN                                 David Attenborough
# 2829  Genndy Tartakovsky  Adam Sandler, Selena Gomez, Kevin James, Kathr...
# 4409     Masahiko Murata  Junko Takeuchi, Chie Nakamura, Rikiya Koyama, ...
#
#              Country       Release_Date Rating  Duration  \
# 4876  United Kingdom  December 25, 2017   TV-G  1 Season
# 2829   United States   January 24, 2019     PG    97 min
# 4409           Japan  September 1, 2017  TV-14    85 min
#
#                                                    Type  \
# 4876  British TV Shows, Docuseries, Science & Nature TV
# ...

# %%
df.iloc[33:37]
# Out:
#    Show_Id Category         Title               Director  \
# 33     s34    Movie  #realityhigh       Fernando Lebrija
# 34     s35    Movie         #Roxy        Michael Kennedy
# 35     s36    Movie     #Rucker50  Robert McCullough Jr.
# 36     s37    Movie       #Selfie         Cristina Jacob
#
#                                                  Cast        Country  \
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 34  Jake Short, Sarah Fisher, Booboo Stewart, Dann...         Canada
# 35                                                NaN  United States
# 36  Flavia Hojda, Crina Semciuc, Olimpia Melinte, ...        Romania
#
#          Release_Date Rating Duration                                    Type  \
# 33  September 8, 2017  TV-14   99 min                                Comedies
# 34     April 10, 2019  TV-14  105 min               Comedies, Romantic Movies
# 35   December 1, 2016  TV-PG   56 min            Documentaries, Sports Movies
# ...

# %%
df.rename(columns={"Show_Id":"ID"},inplace=True)

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.rename(columns = {"ID":"show_Id", "Title":"TTL", "Director":"BTS"},inplace = True)

# %%
df
# Out:
#      show_Id Category                                      TTL  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                     BTS                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.iloc[0]["Show_Id"]=np.nan

# %%
df.iloc[0]["Category"]=np.nan

# %%
df.head(2)
# Out:
#   show_Id Category    TTL                BTS  \
# 0      s1      NaN     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
df.isnull().sum()
# Out:
# show_Id            0
# Category           1
# TTL                0
# BTS             2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3631)

# %%
df.loc[1:4, "Category"] = np.nan

# %%
df
# Out:
#      show_Id Category                                      TTL  \
# 0         s1      NaN                                       3%
# 1         s2      NaN                                    07:19
# 2         s3      NaN                                    23:59
# 3         s4      NaN                                        9
# 4         s5      NaN                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                     BTS                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
d = pd.DataFrame({
    "Age" : [np.nan,np.nan,21,32,44],
    "City" : ["Del","Mum","HR",np.nan,np.nan]
})

# %%
d.isnull().sum()
# Out:
# Age     2
# City    2
# dtype: int64

# %%
d["Age"].fillna(11)
# Out:
# 0    11.0
# 1    11.0
# 2    21.0
# 3    32.0
# 4    44.0
# Name: Age, dtype: float64

# %% [markdown]
# ### For house of Card what is the show id and who is director ?

# %%
df[df["TTL"]=="House of Cards"][["show_Id", "BTS"]]
# Out:
#      show_Id                                                BTS
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# What is the distribution of category column

# %%
df["Category"].value_counts()
# Out:
# Category
# Movie      5375
# TV Show    2409
# Name: count, dtype: int64

# %% [markdown]
# ### How many movies were released in 2020?

# %%
print(len(df[(df['Category'] == 'Movie')]))
# Out:
# 5375

# %%
df["Release_Date"] = pd.to_datetime(df["Release_Date"], format="mixed")
(df['Release_Date'].dt.year == 2020)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7784     True
# 7785    False
# 7786     True
# 7787     True
# 7788     True
# Name: Release_Date, Length: 7789, dtype: bool

# %%
df[(df["Category"]=="Movie")&(df["Release_Date"].dt.year == 2020)]
# Out:
#      show_Id Category                                      TTL  \
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# 30       s31    Movie                         #cats_the_mewvie
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                               BTS  \
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...

# %%
### in which year highest movies were released?
df["Release_Date"] = pd.to_datetime(df["Release_Date"], format="mixed")

# %%
df["Year"]=df["Release_Date"].dt.year

# %%
df[(df["Category"]=="Movie")]['Year'].value_counts().idxmax()
# Out:
# np.float64(2019.0)

# %%
df[(df["Category"]=="Movie")]['Year'].value_counts().idxmin()
# Out:
# np.float64(2010.0)

# %%
df[(df["Category"]=="Movie")]['Year'].value_counts().head(1)
# Out:
# Year
# 2019.0    1498
# Name: count, dtype: int64
